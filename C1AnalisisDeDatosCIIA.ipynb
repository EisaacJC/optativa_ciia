# %% [markdown]
# # Clase de datos 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ds=pd.read_csv("https://raw.githubusercontent.com/htapiagroup/iart-2020/master/_data/patients.dat") #Importar base de datos en dat

# %%
ds #Dataframe que ocupamos
# Out:
#      LastName  Gender  Age                   Location  Height  Weight  Smoker  \
# 0       Smith    Male   38    County General Hospital      71     176       1
# 1     Johnson    Male   43                VA Hospital      69     163       0
# 2    Williams  Female   38  St. Mary's Medical Center      64     131       0
# 3       Jones  Female   40                VA Hospital      67     133       0
# 4       Brown  Female   49    County General Hospital      64     119       0
# ..        ...     ...  ...                        ...     ...     ...     ...
# 95  Alexander    Male   25    County General Hospital      69     171       1
# 96    Russell    Male   44                VA Hospital      69     188       1
# 97    Griffin    Male   49    County General Hospital      70     186       0
# 98       Diaz    Male   45    County General Hospital      68     172       1
# 99      Hayes    Male   48    County General Hospital      66     177       0
#
# ...

# %%
sns.pairplot(data=ds) #pairplots en seaborn

# %%
ds.columns
# Out:
# Index(['LastName', 'Gender', 'Age', 'Location', 'Height', 'Weight', 'Smoker',
#        'Systolic', 'Diastolic', 'SelfAssessedHealthStatus'],
#       dtype='object')

# %%
ds.loc[1]
# Out:
# LastName                        Johnson
# Gender                             Male
# Age                                  43
# Location                    VA Hospital
# Height                               69
# Weight                              163
# Smoker                                0
# Systolic                            109
# Diastolic                            77
# SelfAssessedHealthStatus           Fair
# Name: 1, dtype: object

# %%
type(ds.loc[1]),ds.loc[0]
# Out:
# (pandas.core.series.Series,
#  LastName                                      Smith
#  Gender                                         Male
#  Age                                              38
#  Location                    County General Hospital
#  Height                                           71
#  Weight                                          176
#  Smoker                                            1
#  Systolic                                        124
#  Diastolic                                        93
#  SelfAssessedHealthStatus                  Excellent
#  Name: 0, dtype: object)

# %%
ds.loc[1],ds.loc[2] #leer renglones en pandas
# Out:
# (LastName                        Johnson
#  Gender                             Male
#  Age                                  43
#  Location                    VA Hospital
#  Height                               69
#  Weight                              163
#  Smoker                                0
#  Systolic                            109
#  Diastolic                            77
#  SelfAssessedHealthStatus           Fair
#  Name: 1, dtype: object,
#  LastName                                     Williams
#  Gender                                         Female
#  Age                                                38
#  Location                    St. Mary's Medical Center
#  Height                                             64
#  Weight                                            131
#  Smoker                                              0
#  Systolic                                          125
#  Diastolic                                          83
# ...

# %%
ds.dtypes
# Out:
# LastName                    object
# Gender                      object
# Age                          int64
# Location                    object
# Height                       int64
# Weight                       int64
# Smoker                       int64
# Systolic                     int64
# Diastolic                    int64
# SelfAssessedHealthStatus    object
# dtype: object

# %%
ds["Smoker"]
# Out:
# 0     1
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 95    1
# 96    1
# 97    0
# 98    1
# 99    0
# Name: Smoker, Length: 100, dtype: int64
