# %%
import os
os.chdir('/content/sample_data/')

# %%
import pandas as pd

# %%
from zipfile import ZipFile
import numpy as np

# %%
z=ZipFile('StormEvents.zip')

events=pd.read_csv(z.open(z.infolist()[10].filename))

# %%
print(events.keys())
# Out:
# Index(['EpisodeID', 'Event_ID', 'State', 'Year', 'Month', 'Event_Type',
#        'Begin_Date_Time', 'Timezone', 'End_Date_Time', 'Injuries_Direct',
#        'Injuries_Indirect', 'Deaths_Direct', 'Deaths_Indirect',
#        'Damage_Property', 'Property_Cost', 'Damage_Crops', 'Crop_Cost',
#        'Begin_Lat', 'Begin_Lon', 'End_Lat', 'End_Lon', 'Episode_Narrative',
#        'Event_Narrative'],
#       dtype='object')

# %% [markdown]
# ## **EJERCICIO 1**
# El mes con más tornados fue Junio

# %%
events.Month.value_counts()
# Out:
# June         9082
# July         7375
# May          7089
# August       5781
# April        5504
# January      5008
# March        4855
# February     4250
# September    3932
# October      3039
# November     2917
# December     2910
# Name: Month, dtype: int64

# %% [markdown]
# ## **EJERCICIO 2**
#
# El tipo de evento en tercer lugar en "Flood"

# %%
events.Event_Type.value_counts()
# Out:
# Thunderstorm Wind             14585
# Hail                           7861
# Flood                          4715
# Winter Weather                 4478
# Flash Flood                    4358
# Winter Storm                   3375
# High Wind                      2944
# Drought                        2410
# Heavy Snow                     2220
# Marine Thunderstorm Wind       2090
# Heavy Rain                     1899
# Heat                           1282
# Tornado                        1248
# Strong Wind                    1021
# Dense Fog                       752
# Blizzard                        748
# Frost/Freeze                    701
# Extreme Cold/Wind Chill         590
# High Surf                       531
# Cold/Wind Chill                 523
# Excessive Heat                  437
# Wildfire                        416
# Lightning                       393
# Funnel Cloud                    349
# Coastal Flood                   320
# Tropical Storm                  317
# ...

# %% [markdown]
# ## **EJERCICIO 3**

# %%
hw1=events=pd.read_csv("hw1.csv")

# %%
print(hw1.keys())
# Out:
# Index(['Unnamed: 0', 'region', 'area', 'palmitic', 'palmitoleic', '"stearic"',
#        'oleic', 'linoleic', 'linolenic', 'arachidic', 'eicosenoic'],
#       dtype='object')

# %% [markdown]
# ## **EJERCICIO 3 A)**

# %%
hw1.dtypes
# Out:
# Unnamed: 0     object
# region          int64
# area            int64
# palmitic        int64
# palmitoleic    object
# "stearic"      object
# oleic          object
# linoleic       object
# linolenic      object
# arachidic      object
# eicosenoic     object
# dtype: object

# %%
import matplotlib

# %%
hw1=events=pd.read_csv("hw1_2.csv")

# %%
hw1.dtypes
# Out:
# Unnamed: 0     object
# region          int64
# area            int64
# palmitic        int64
# palmitoleic     int64
# "stearic"       int64
# oleic           int64
# linoleic        int64
# linolenic       int64
# arachidic       int64
# eicosenoic      int64
# dtype: object

# %% [markdown]
# ## **EJERCICIO 3 B)**

# %%
hw1["palmitoleic"].plot()

# %%
hw1['"stearic"'].plot()

# %%
hw1["oleic"].plot()

# %%
hw1["linoleic"].plot()

# %%
hw1["linolenic"].plot()

# %%
hw1["arachidic"].plot()

# %%
hw1["eicosenoic"].plot()

# %% [markdown]
# ## **EJERCICIO 3 C)**

# %%
hw1.plot.scatter(x='eicosenoic',y='palmitoleic')
